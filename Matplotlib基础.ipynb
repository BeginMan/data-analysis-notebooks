# %%
# %matplotlib inline

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 画布与图型(Figure and Axis)

# %%
x = np.linspace(-5, 2, 100)
y1 = x ** 3 + 5 * x ** 2 + 100
y2 = 3 * x ** 2 + 10 * x
y3 = 6 * x + 10
y4 = x ** 2

# %%
plt.plot(x, y1)
